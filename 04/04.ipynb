# %% [markdown]
# # Python 流程控制语句
# 程序并非总是“从上到下”顺序执行，我们可以根据条件做出选择，或者重复执行某些代码。这就是**流程控制**。
# 本 Notebook 将带你系统地学习：
# 1. 分支语句（if / elif / else）
# 2. 循环语句（while / for）
# 3. 嵌套与综合案例

# %% [markdown]
# ## 1. 单分支

# %%
# 01_单分支
# 语法：if 条件:
#         条件成立时执行的代码

age = int(input('请输入你的年龄：'))
if age >= 18:
    print('你是成年人')
    print('成年人的世界，虽不容易，但很精彩！')
print('欢迎你学习 Python！')
# Out:
# 欢迎你学习 Python！

# %% [markdown]
# ## 2. 双分支

# %%
# 02_双分支
# 语法：if 条件:
#           ...
#       else:
#           ...

age = int(input('请输入你的年龄：'))
if age >= 18:
    print('你是成年人')
    print('成年人的世界，虽不容易，但很精彩！')
else:
    print('你是未成年人')
    print('好好加油，努力学习，未来可期！')
print('欢迎你学习 Python！')
# Out:
# 你是未成年人
# 好好加油，努力学习，未来可期！
# 欢迎你学习 Python！

# %% [markdown]
# ## 3. 多分支

# %%
# 03_多分支
# 语法：if 条件1:
#           ...
#       elif 条件2:
#           ...
#       else:
#           ...

age = int(input('请输入你的年龄：'))
if age <= 10:
    print('你是幼儿')
elif age <= 18:
    print('你是青少年')
elif age <= 30:
    print('你是青年')
elif age <= 50:
    print('你是中年')
elif age <= 60:
    print('你是中老年')
else:
    print('你是老年')
# Out:
# 你是幼儿

# %% [markdown]
# ## 4. 嵌套分支

# %%
# 04_嵌套分支
# 在一个分支内部再写分支，实现更复杂的逻辑判断。

age = int(input('请输入你的年龄：'))
has_report = input('您是否提交了体检报告？（是/否）')
level = int(input('请输入你的会员等级（1/2/3）'))

print('******⬇️程序的识别结果如下⬇️：******')
if 18 <= age <= 45:
    print('✅️您的年龄符合比赛要求！')
    if has_report == '是':
        print('✅️您已提交体检报告！')
        print('✅️您可以参加比赛！')
        if level == 1:
            print(f'😊尊敬的{level}会员，比赛结束后，您可以领取纪念T恤👕一件！')
        elif level == 2:
            print(f'😊尊敬的{level}会员，比赛结束后，您可以领取专业跑鞋👟一双！')
        elif level == 3:
            print(f'😊尊敬的{level}会员，比赛结束后，您可以领取运动耳机🎧一副！')
        else:
            print('❌您输入的会员等级不正确！')
    elif has_report == '否':
        print('❌您未提交体检报告，不能参加比赛！')
    else:
        print('❌您输入的体检报告有误！')
else:
    print('❌抱歉，参赛年龄需要在18~45之间！')
# Out:
# ******⬇️程序的识别结果如下⬇️：******
# ❌抱歉，参赛年龄需要在18~45之间！

# %% [markdown]
# ## 5. while 循环

# %%
# 05_while_循环
# 语法：while 条件:
#          循环体
# 注意避免死循环！

n = 1
while n <= 10:
    print(f'第{n}次你好啊')
    n += 1
print(f'循环结束，此时的 n = {n}')
# Out:
# 第1次你好啊
# 第2次你好啊
# 第3次你好啊
# 第4次你好啊
# 第5次你好啊
# 第6次你好啊
# 第7次你好啊
# 第8次你好啊
# 第9次你好啊
# 第10次你好啊
# 循环结束，此时的 n = 11

# %% [markdown]
# ## 6. while 循环案例（密室逃脱）

# %%
# 06_while_循环案例
print('😦您现在身处密室，需要正确回答问题之后，才能逃出密室！')
riddle = '你是什么人？'
answer = '你的心上人'
guess = ''

while guess != answer:
    print(f'问题：{riddle}')
    guess = input('请输入答案：')
    if guess == answer:
        print('✅️答案正确，逃脱成功！')
    else:
        print('❌️回答错误，请再想想！')
# Out:
# 😦您现在身处密室，需要正确回答问题之后，才能逃出密室！
# 问题：你是什么人？
# ❌️回答错误，请再想想！
# 问题：你是什么人？
# ✅️答案正确，逃脱成功！

# %% [markdown]
# ## 7. for 循环

# %%
# 07_for_循环
# 语法：for 临时变量 in 可迭代对象:
#          循环体
# 可迭代对象：能一个个取出来的，如 range()、字符串、列表等。

# 遍历数字范围
print('--- for + range ---')
for n in range(1, 11):
    print(f'第{n}次你好啊')
print(f'循环结束，最后的 n = {n}')

# 遍历字符串
print('\n--- 遍历字符串 ---')
for ch in 'abcdef':
    print(ch)

# 遍历列表（注意不要边遍历边修改列表大小）
print('\n--- 遍历列表 ---')
nums = [1, 2, 3]
for i in nums:
    print(i)
    # nums.append(4)  # 危险操作，会造成死循环或意外
# Out:
# --- for + range ---
# 第1次你好啊
# 第2次你好啊
# 第3次你好啊
# 第4次你好啊
# 第5次你好啊
# 第6次你好啊
# 第7次你好啊
# 第8次你好啊
# 第9次你好啊
# 第10次你好啊
# 循环结束，最后的 n = 10
#
# --- 遍历字符串 ---
# a
# b
# c
# d
# e
# f
#
# --- 遍历列表 ---
# 1
# 2
# 3

# %% [markdown]
# ## 8. for 循环案例（字符串加解密）

# %%
# 08_for_循环案例
# 利用字符编码进行简单的“凯撒密码”加解密

# 加密
text = input('📝请输入要加密的文字：')
secret = ''
for t in text:
    secret += chr(ord(t) + 1)
print(f'㊙️加密后：{secret}')

# 解密
secret = input('📝请输入要解密的文字：')
text = ''
for s in secret:
    text += chr(ord(s) - 1)
print(f'📃解密后：{text}')
# Out:
# ㊙️加密后：ihte
# 📃解密后：hgsd

# %% [markdown]
# ## 9. 嵌套循环

# %%
# 09_嵌套循环
# 案例：为期 30 天的健身计划

print('=== for 循环实现 ===')
for day in range(1, 31):
    print(f'********📅第{day}天********')
    for group in range(1, 4):
        print(f'💪这是第{group}组仰卧起坐')
    print(f'✅第{day}天任务已完成！明天继续！\n')
print(f'🎉为期{day}天的健身计划完成，我的腹肌在闪闪发光！')
# Out:
# === for 循环实现 ===
# ********📅第1天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第1天任务已完成！明天继续！
#
# ********📅第2天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第2天任务已完成！明天继续！
#
# ********📅第3天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第3天任务已完成！明天继续！
#
# ********📅第4天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第4天任务已完成！明天继续！
#
# ********📅第5天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅
********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第22天任务已完成！明天继续！
#
# ********📅第23天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第23天任务已完成！明天继续！
#
# ********📅第24天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第24天任务已完成！明天继续！
#
# ********📅第25天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第25天任务已完成！明天继续！
#
# ********📅第26天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第26天任务已完成！明天继续！
#
# ********📅第27天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第27天任务已完成！明天继续！
#
# ********📅第28天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第28天任务已完成！明天继续！
#
# ********📅第29天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第29天任务已完成！明天继续！
#
# ********📅第30天********
# 💪这是第1组仰卧起坐
# 💪这是第2组仰卧起坐
# 💪这是第3组仰卧起坐
# ✅第30天任务已完成！明天继续！
#
# 🎉为期30天的健身计划完成，我的腹肌在闪闪发光！

# %% [markdown]
# ## 10. 九九乘法表

# %%
# 10_九九乘法表
# 通过 end 参数控制打印结尾符

# 先理解 end 的用法
print('你好', end='')
print('世界')          # 输出：你好世界
print('你好', end='---')
print('世界')          # 输出：你好---世界

print('\n====== 九九乘法表 ======')
for row in range(1, 10):
    for col in range(1, row + 1):
        print(f'{col}*{row}={col * row}', end='\t')
    print()  # 换行
# Out:
# 你好世界
# 你好---世界
#
# ====== 九九乘法表 ======
# 1*1=1
# 1*2=2	2*2=4
# 1*3=3	2*3=6	3*3=9
# 1*4=4	2*4=8	3*4=12	4*4=16
# 1*5=5	2*5=10	3*5=15	4*5=20	5*5=25
# 1*6=6	2*6=12	3*6=18	4*6=24	5*6=30	6*6=36
# 1*7=7	2*7=14	3*7=21	4*7=28	5*7=35	6*7=42	7*7=49
# 1*8=8	2*8=16	3*8=24	4*8=32	5*8=40	6*8=48	7*8=56	8*8=64
# 1*9=9	2*9=18	3*9=27	4*9=36	5*9=45	6*9=54	7*9=63	8*9=72	9*9=81

# %% [markdown]
# ## 11. continue 与 break

# %%
# 11_continue与break
# continue：跳过本次循环剩余语句，继续下一次循环
# break：立即终止整个循环

# ---------- continue 示例 ----------
print('=== continue 示例 ===')
for day in range(1, 5):
    print(f'********第{day}天********')
    print('吃饭')
    if day == 2:
        continue  # 第2天不睡觉
    print('睡觉')

print('\n--- 嵌套中的 continue ---')
for day in range(1, 5):
    print(f'********第{day}天********')
    print('吃饭')
    for item in range(1, 3):
        print(f'面包{item}')
        if day == 4 and item == 2:
            continue  # 第4天第2个面包后不喝牛奶
        print(f'牛奶{item}')
    print('睡觉')

# ---------- break 示例 ----------
print('\n=== break 示例 ===')
for day in range(1, 5):
    print(f'********第{day}天********')
    print('吃饭')
    if day == 2:
        break  # 第2天直接结束所有循环
    print('睡觉')

print('\n--- 嵌套中的 break ---')
for day in range(1, 5):
    print(f'********第{day}天********')
    print('吃饭')
    for item in range(1, 3):
        print(f'面包{item}')
        if day == 4 and item == 2:
            break  # 仅跳出内层循环
        print(f'牛奶{item}')
    print('睡觉')
# Out:
# === continue 示例 ===
# ********第1天********
# 吃饭
# 睡觉
# ********第2天********
# 吃饭
# ********第3天********
# 吃饭
# 睡觉
# ********第4天********
# 吃饭
# 睡觉
#
# --- 嵌套中的 continue ---
# ********第1天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第2天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第3天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第4天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 睡觉
#
# === break 示例 ===
# ********第1天********
# 吃饭
# 睡觉
# ********第2天********
# 吃饭
#
# --- 嵌套中的 break ---
# ********第1天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第2天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第3天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 牛奶2
# 睡觉
# ********第4天********
# 吃饭
# 面包1
# 牛奶1
# 面包2
# 睡觉

# %% [markdown]
# ## 12. 综合案例：答题闯关挑战赛

# %%
# 12_综合案例
# 结合分支、循环、continue、break，实现一个答题游戏

print('🏆欢迎来到：答题闯关挑战赛（输入q可随时退出）\n')

# 题库
ques1, ans1 = 'Python中用于输出的函数是？', 'print'
ques2, ans2 = 'Python中用于表示逻辑“并且”的关键字是？', 'and'
ques3, ans3 = 'Python属于编译型还是解释型？', '解释型'

max_tries = 3        # 每关最多尝试次数
total_levels = 3     # 总关卡数
is_playing = True    # 游戏状态

for level in range(1, total_levels + 1):
    print(f'********🎯第{level}关********')
    if level == 1:
        question, answer = ques1, ans1
    elif level == 2:
        question, answer = ques2, ans2
    else:
        question, answer = ques3, ans3

    tries = 1
    while tries <= max_tries:
        user_input = input('📢' + question)
        if user_input == answer:
            print('✅回答正确！\n')
            break
        elif user_input == '':
            print('⚠️您的输入为空，请重新作答！\n')
            continue
        elif user_input == 'q':
            print('👋您已退出游戏！\n')
            is_playing = False
            break
        else:
            leave = max_tries - tries
            if leave > 0:
                print(f'❌回答错误，您还剩{leave}次机会！\n')
                tries += 1
                continue
            else:
                print(f'😢挑战失败，正确答案是：{answer}，游戏结束！')
                is_playing = False
                break

    if not is_playing:
        break

if is_playing:
    print('🎉🎉🎉恭喜您！全部通关！🎉🎉🎉')
# Out:
# 🏆欢迎来到：答题闯关挑战赛（输入q可随时退出）
#
# ********🎯第1关********
# ✅回答正确！
#
# ********🎯第2关********
# ✅回答正确！
#
# ********🎯第3关********
# ✅回答正确！
#
# 🎉🎉🎉恭喜您！全部通关！🎉🎉🎉

# %% [markdown]
# ## 练习与思考
# 1. 修改嵌套分支中的比赛案例，增加一个“VIP通道”判断。
# 2. 用 while 循环实现九九乘法表。
# 3. 在答题游戏中增加第4关，并自定义题目。
# 4. 分析什么时候适合用 for，什么时候适合用 while。
